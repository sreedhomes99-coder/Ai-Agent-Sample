# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

# %%
llm=init_chat_model("google_genai:gemini-3-pro") 

# Invoke the model
response = llm.invoke("Hello, how can I help you today?")
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 llm=init_chat_model("google_genai:gemini-3-pro")
#       3 # Invoke the model
#       4 response = llm.invoke("Hello, how can I help you today?")
#
# File c:\Sreedhar\Python_learn\Ai Agent Sample\venv\Lib\site-packages\langchain\chat_models\base.py:314, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     306     warnings.warn(
#     307         f"{config_prefix=} has been set but no fields are configurable. Set "
#     308         f"`configurable_fields=(...)` to specify the model params that are "
#     309         f"configurable.",
#     310         stacklevel=2,
#     311     )
#     313 if not configurable_fields:
# --> 314     return _init_chat_model_helper(
#     315         cast("str", model),
#     316         model_provider=model_provider,
# ...
